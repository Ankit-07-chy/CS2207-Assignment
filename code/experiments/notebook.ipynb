# %% [markdown]
# # Start Of Notebook

# %%
# Importing 
import os 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the data
from pathlib import Path

# Find the repository root by walking upward until a known file exists.
root = Path.cwd().resolve()
while not (root / 'pyproject.toml').exists() and root != root.parent:
    root = root.parent

file_path = root / 'data' / 'credit_card_usage.csv'
data = pd.read_csv(file_path)

# %%
# Showing the first few rows of the dataset
display(data.head())
print("#"*100)
print(data.info())
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12
# ####################################################################################################
# <class 'pandas.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   str
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), str(1)
# memory usage: 1.2 MB
# None

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
# Columns Uisng
data.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='str')

# %%
data = data.drop('CUST_ID', axis=1)

# %%
data.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# Taking Care of Missing Values
data['MINIMUM_PAYMENTS'] = data['MINIMUM_PAYMENTS'].fillna(
    data['MINIMUM_PAYMENTS'].median()
)

data.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        1
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# CREDIT LIMIT remove none
data = data.dropna(subset=['CREDIT_LIMIT'])

# %%
# For Transforming the data, we will use the log transformation to reduce the skewness of the data.
skewed_cols = ['BALANCE', 'PURCHASES', 'ONEOFF_PURCHASES',
               'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
               'PAYMENTS', 'MINIMUM_PAYMENTS']

for col in skewed_cols:
    data[col] = np.log1p(data[col])

# %%
# Feature Scaling 
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# %%
scaled_data = pd.DataFrame(scaled_data, columns=data.columns)

# %%
scaled_data
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    -1.205498          -0.249881  -0.113732         -0.987198
# 1     0.948821           0.134049  -1.680213         -0.987198
# 2     0.824885           0.517980   0.600600          1.061910
# 3     0.624529          -1.017743   0.827395          1.265665
# 4     0.271106           0.517980  -0.708741         -0.114417
# ...        ...                ...        ...               ...
# 8944 -1.379929           0.517980   0.266413         -0.987198
# 8945 -1.568362           0.517980   0.276681         -0.987198
# 8946 -1.474137          -0.185895   0.027189         -0.987198
# 8947 -1.734100          -0.185895  -1.680213         -0.987198
# 8948 -0.118488          -0.889766   0.719250          1.168507
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   0.394362     -0.930636            -0.806649
# 1                  -1.087586      1.528788            -1.221928
# 2                  -1.087586     -0.930636             1.269742
# 3                  -1.087586      0.564410            -1.014290
# 4                  -1.087586     -0.930636            -1.014290
# ...                      ...           ...                  ...
# 8944                0.753993     -0.930636             1.269742
# 8945                0.763707     -0.930636             1.269742
# 8946                0.527678     -0.930636             0.854463
# 8947               -1.087586      0.086095            -1.221928
# 8948               -1.087586      0.429996             0.439186
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                      -0.678716                         -0.707409
# 1                      -0.678716                         -0.917090
# 2                       2.673295                         -0.917090
# 3                      -0.399383                         -0.917090
# 4                      -0.399383                         -0.917090
# ...                          ...                               ...
# 8944                   -0.678716                          1.179720
# 8945                   -0.678716                          1.179720
# 8946                   -0.678716                          0.760359
# 8947                   -0.678716                         -0.917090
# 8948                    1.555959                         -0.917090
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                  -0.675294         -0.476083      -0.511381     -0.960380
# 1                   0.573949          0.110032      -0.591841      0.688601
# 2                  -0.675294         -0.476083      -0.109082      0.826016
# 3                  -0.258882         -0.329554      -0.551611      0.826016
# 4                  -0.675294         -0.476083      -0.551611     -0.905414
# ...                      ...               ...            ...           ...
# 8944               -0.675294         -0.476083      -0.350461     -0.960380
# 8945               -0.675294         -0.476083      -0.350461     -0.960380
# 8946               -0.675294         -0.476083      -0.390691     -0.960380
# 8947                0.157536         -0.183026      -0.591841     -1.097795
# 8948                0.990362         -0.183026       0.333446     -0.905414
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# 0    -0.825080         -0.830442         -0.525588  0.360541
# 1     1.065109          0.908205          0.234159  0.360541
# 2    -0.119646          0.450264         -0.525588  0.360541
# 3    -4.163779         -0.144626         -0.525588  0.360541
# 4    -0.065306         -0.352262         -0.525588  0.360541
# ...        ...               ...               ...       ...
# 8944 -0.525611         -1.715929          1.183844 -4.126919
# 8945 -0.629439         -0.144626         -0.525588 -4.126919
# 8946 -1.392116         -1.276301          0.329128 -4.126919
# 8947 -1.661991         -1.605614          0.329128 -4.126919
# 8948 -1.548329         -1.218146         -0.525588 -4.126919
#
# [8949 rows x 17 columns]

# %%
# Test different MinPts values
from sklearn.neighbors import NearestNeighbors
for min_pts in [3, 5, 10, 15]:
    neighbors = NearestNeighbors(n_neighbors=min_pts)
    neighbors.fit(scaled_data)
    distances, _ = neighbors.kneighbors(scaled_data)
    distances = np.sort(distances[:, min_pts-1])
    plt.plot(distances, label=f'MinPts={min_pts}')

plt.legend()
plt.title("K-Distance Plots for Different MinPts")
plt.show()

# %%
# k-distance plot to determine the optimal epsilon value for DBSCAN
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import numpy as np

neighbors = NearestNeighbors(n_neighbors=5)
neighbors_fit = neighbors.fit(scaled_data)
distances, indices = neighbors_fit.kneighbors(scaled_data)

distances = np.sort(distances[:, 3])  # 4 = MinPts-1
plt.plot(distances)
plt.title("K-Distance Plot")
plt.show()

# %%
# Apply DBSCAN
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1.5, min_samples=3)  # adjust eps from plot
labels = dbscan.fit_predict(scaled_data)

data['Cluster'] = labels

# %%
set(labels)
# Out:
# {np.int64(-1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(17),
#  np.int64(18),
#  np.int64(19),
#  np.int64(20),
#  np.int64(21),
#  np.int64(22),
#  np.int64(23),
#  np.int64(24),
#  np.int64(25),
#  np.int64(26),
#  np.int64(27),
#  np.int64(28),
#  np.int64(29),
#  np.int64(30),
#  np.int64(31),
#  np.int64(32),
#  np.int64(33),
#  np.int64(34),
#  np.int64(35),
#  np.int64(36),
#  np.int64(37),
#  np.int64(38),
#  np.int64(39),
#  np.int64(40),
#  np.int64(41),
#  np.int64(42),
#  np.int64(43),
#  np.int64(44),
#  np.int64(45)}

# %%
data['Cluster'].value_counts()
# Out:
# Cluster
#  0     7630
# -1      994
#  5       44
#  14      30
#  12      23
#  21      23
#  1       17
#  13      13
#  2       12
#  4       12
#  3       10
#  23       9
#  9        8
#  10       6
#  18       6
#  30       6
#  29       5
#  26       5
#  28       5
#  8        4
#  11       4
#  27       4
#  34       4
#  16       4
#  31       4
#  37       4
#  6        3
#  7        3
#  15       3
#  17       3
#  19       3
#  38       3
#  20       3
#  22       3
#  35       3
#  24       3
#  25       3
#  36       3
#  41       3
#  40       3
#  44       3
#  32       3
#  33       3
#  45       3
#  39       3
#  43       3
#  42       3
# Name: count, dtype: int64

# %%
outliers = data[data['Cluster'] == -1]

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
reduced = pca.fit_transform(scaled_data)

plt.scatter(reduced[:,0], reduced[:,1], c=labels)
plt.title("DBSCAN Clusters (PCA)")
plt.show()

# %%
# Profiling Outliers (Noise Points)
print("="*80)
print("OUTLIER PROFILING")
print("="*80)
print(f"\nTotal outliers detected: {len(outliers)}")
print(f"Percentage of outliers: {len(outliers)/len(data)*100:.2f}%\n")

# Statistics of outliers vs normal points
normal_points = data[data['Cluster'] != -1]

print("Outliers Summary Statistics:")
print(outliers[['BALANCE', 'PURCHASES', 'PAYMENTS', 'MINIMUM_PAYMENTS']].describe())

print("\n" + "-"*80)
print("Normal Points Summary Statistics:")
print(normal_points[['BALANCE', 'PURCHASES', 'PAYMENTS', 'MINIMUM_PAYMENTS']].describe())

print("\n" + "-"*80)
print("Mean Comparison (Outliers vs Normal):")
comparison = pd.DataFrame({
    'Outliers Mean': outliers[['BALANCE', 'PURCHASES', 'PAYMENTS', 'MINIMUM_PAYMENTS']].mean(),
    'Normal Mean': normal_points[['BALANCE', 'PURCHASES', 'PAYMENTS', 'MINIMUM_PAYMENTS']].mean()
})
print(comparison)

print("\n" + "="*80)
print("Outlier Characteristics:")
print("="*80)
print(outliers.head(20))
###########
#########
# Out:
# ================================================================================
# OUTLIER PROFILING
# ================================================================================
#
# Total outliers detected: 994
# Percentage of outliers: 11.11%
#
# Outliers Summary Statistics:
#           BALANCE   PURCHASES    PAYMENTS  MINIMUM_PAYMENTS
# count  994.000000  994.000000  994.000000        994.000000
# mean     6.356633    5.969485    7.049293          6.055680
# std      2.250145    2.627148    2.262786          1.603927
# min      0.000000    0.000000    0.000000          0.018982
# 25%      5.120089    5.139643    6.211944          5.042935
# 50%      6.840252    6.590837    7.493037          5.836275
# 75%      8.095759    7.695304    8.492514          7.149347
# max      9.854515   10.800403   10.834125         11.243832
#
# --------------------------------------------------------------------------------
# Normal Points Summary Statistics:
#            BALANCE    PURCHASES     PAYMENTS  MINIMUM_PAYMENTS
# count  7955.000000  7955.000000  7955.000000       7955.000000
# mean      6.137674     4.766584     6.572009          5.899035
# std       1.980337     2.923534     1.477765          1.102175
# min       0.000000     0.000000     0.000000          0.037049
# 25%       4.828075     3.044522     5.935322          5.149625
# 50%       6.766704     5.818955     6.690246          5.747301
# 75%       7.574136     6.929169     7.446844          6.624156
# max       9.825340    10.390249    10.437289         11.019164
#
# --------------------------------------------------------------------------------
# Mean Comparison (Outliers vs Normal):
#                   Outliers Mean  Normal Mean
# BALANCE                6.356633     6.137674
# PURCHASES              5.969485     4.766584
# PAYMENTS               7.049293     6.572009
# MINIMUM_PAYMENTS       6.055680     5.899035
#
# ================================================================================
# Outlier Characteristics:
# ================================================================================
#       BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 3    7.419183           0.636364   7.313220          7.313220
# 23   8.243059           0.818182   8.354521          8.147740
# 30   9.404032           1.000000   8.019287          6.921855
# 34   8.165677           0.727273   6.306786          0.000000
# 39   7.253189           0.454545   6.871340          6.871340
# 45   7.715708           1.000000   6.082219          4.584967
# 46   6.164256           0.500000   4.707185          0.000000
# 50   8.503567           1.000000   6.805080          6.472454
# 53   6.143486           0.888889   7.590963          7.590963
# 71   8.003504           0.909091   8.417212          7.417634
# 81   4.413825           0.272727   0.000000          0.000000
# 86   8.863750           1.000000   7.380742          7.276653
# 87   9.009723           1.000000   7.722682          7.185220
# 90   9.146575           1.000000   8.537206          7.046499
# 99   0.000000           0.000000   0.000000          0.000000
# 109  8.801650           1.000000   8.407323          7.909339
# 120  9.048513           1.000000   8.813626          8.319006
# 122  7.656885           1.000000   8.627276          0.000000
# 125  7.780687           1.000000   9.430555          9.430555
# 128  9.320829           1.000000   5.021509          5.021509
#
#      INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 3                  0.000000      5.331694             0.083333
# 23                 6.678078      8.984119             1.000000
# 30                 7.613725      8.066077             1.000000
# 34                 6.306786      0.000000             1.000000
# 39                 0.000000      8.728213             0.083333
# 45                 5.831882      5.223856             0.333333
# 46                 4.707185      6.922308             0.375000
# 50                 5.546544      9.051538             0.625000
# 53                 0.000000      7.591996             0.666667
# 71                 7.958640     10.214550             0.666667
# 81                 0.000000      8.001790             0.000000
# 86                 5.072921      8.635332             1.000000
# 87                 6.846125      8.566408             1.000000
# 90                 8.282291      5.918187             1.000000
# 99                 0.000000      4.509199             0.000000
# 109                7.472023      8.882742             1.000000
# 120                7.872905      7.431063             1.000000
# 122                8.627276      0.000000             1.000000
# 125                0.000000      0.000000             0.916667
# 128                0.000000      9.031591             0.083333
#
#      ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 3                      0.083333                          0.000000
# 23                     0.083333                          0.916667
# 30                     0.166667                          1.000000
# 34                     0.000000                          1.000000
# 39                     0.083333                          0.000000
# 45                     0.083333                          0.333333
# 46                     0.000000                          0.250000
# 50                     0.375000                          0.250000
# 53                     0.666667                          0.000000
# 71                     0.500000                          0.583333
# 81                     0.000000                          0.000000
# 86                     0.833333                          1.000000
# 87                     0.750000                          1.000000
# 90                     0.250000                          0.916667
# 99                     0.000000                          0.000000
# 109                    0.916667                          1.000000
# 120                    0.916667                          1.000000
# 122                    0.000000                          1.000000
# 125                    0.916667                          0.000000
# 128                    0.083333                          0.000000
#
#      CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 3                  0.083333                 1              1        7500.0
# 23                 0.333333                13             13        9000.0
# 30                 0.500000                10             64       13000.0
# 34                 0.000000                 0             14       11000.0
# 39                 0.333333                 6              6        7500.0
# 45                 0.166667                 2              5        2400.0
# 46                 0.125000                 1              3        1700.0
# 50                 0.875000                37              9       12000.0
# 53                 0.111111                 1             11        3000.0
# 71                 0.833333                27             33        7000.0
# 81                 0.166667                 5              0        9500.0
# 86                 0.750000                23             23       11000.0
# 87                 0.750000                21             60       13500.0
# 90                 0.083333                 1             46        9000.0
# 99                 0.142857                 1              0        3000.0
# 109                0.583333                21             64        9000.0
# 120                0.500000                10             85       17000.0
# 122                0.000000                 0             75        8500.0
# 125                0.000000                 0            217        2800.0
# 128                0.500000                14              1       17000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  Cluster
# 3     0.000000          5.747301          0.000000      12       -1
# 23    9.156944          7.262928          0.000000      12       -1
# 30    8.350270          8.099559          0.000000      12       -1
# 34    9.075277          9.790518          0.000000      12       -1
# 39    9.907085          6.580568          0.333333      12       -1
# 45    0.000000          5.747301          0.000000      12       -1
# 46    5.176223          4.998561          0.000000       8       -1
# 50    9.001383          6.921082          0.000000       8       -1
# 53    8.042716          4.893698          0.200000       9       -1
# 71   10.248271          7.010340          0.454545      12       -1
# 81    4.767026          5.110131          0.000000      12       -1
# 86    8.431826          7.537570          0.000000      12       -1
# 87    8.013865          7.637997          0.000000      12       -1
# 90    8.765692          9.192995          0.000000      12       -1
# 99    4.934628          5.747301          0.000000       7       -1
# 109   9.292744          7.812205          0.083333      12       -1
# 120   7.544203          7.681766          0.000000      12       -1
# 122   8.179194          6.447312          0.000000      12       -1
# 125   9.361319          7.601897          0.000000      12       -1
# 128   7.865978          7.970767          0.000000      12       -1
